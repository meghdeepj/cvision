# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../data/rgb.jpeg', 1)

# %%
plt_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
n_img=np.zeros(img.shape)
n_img=cv2.normalize(img, n_img, 0, 1, cv2.NORM_MINMAX)

# %%
n_plt_img=np.zeros(img.shape)
n_plt_img=cv2.normalize(plt_img, n_plt_img, 0, 1, cv2.NORM_MINMAX)

# %%
print(img[100,100],n_img[100,100])
# Out:
# [  6 254 254] [0 1 1]

# %%
f, axarr = plt.subplots(1,2)
axarr[0].imshow(plt_img)
axarr[1].imshow(n_plt_img)

# %%
cv2.imshow('image_og',img)
cv2.imshow('image_norm',n_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# cv2.imwrite('../data/mona_gray.jpg', img)

# %%
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.show()

# %%
img1 = cv2.imread('../data/goldhill.bmp', 1)

# %%
cv2.imshow('image_og',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
l_img=cv2.line(img1,(0,0), (255,255), (255,255,0), 5)

# %%
cv2.imshow('image_line',l_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img1[90,100,0])
# Out:
# 125

# %%
type(img1)
# Out:
# numpy.ndarray
